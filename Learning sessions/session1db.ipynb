# %%
number_of_student= 33
name_of_student="H.Zahra"
print(number_of_student,name_of_student)
#variable is a term created to store some value
#datatype check
print(type(number_of_student))
print(type(name_of_student))
float_var=5.5
print(type(float_var))
#sequence type variable
#lists:can be updated or changed list of student
fruits=["banana", "kiwi", "orange", "mango"]
print(fruits)
#tuple:can not be changed or updated and immutable, for example course rating
fruits_tuple=("banana", "kiwi", "orange", "mango")
print(fruits_tuple)
#range: sequence of numbers
range_of_number = range(100)
print(range_of_number )
student_names=["hina","gia","ria"]
print(student_names)
Student_names_tuple=("hira","jia","bia")
print(Student_names_tuple)
##mapping variable is like dictionary like defination of term or word
#called key:value for example
all_stu_profile={
"stu_profile1":{
    "name":"mary",
    "age": 24,
    "course":"data09",
    "gpa":3.4
},

"stu_profile2":{
    "name":"jame",
    "age": 24,
    "course":"data09",
    "gpa":3.0


}
}
print(all_stu_profile)
all_teach_profile={
"teach_profile1":{
    "name":"rabia",
    "age": 30,
    "course":"data09"

},

"teach_profile2":{
    "name":"owais",
    "age": 30,
    "course_teaching":"datascience09"



}
}
print(all_teach_profile)
#set type variable
#two types Set  have no duplicates, and changes can be made to the set variable distinct
set_var={1,4,4,5}
print(set_var)
#Frozenset variable :cannot change
feozen_set=[1,2,3,4]
print(feozen_set)
set_var.add(6)
print(set_var)
##boolean is yes,no
is_student=True
is_enrolled=False
print(is_student,is_enrolled)
#Arithmetic operators
a=20
b=6
sum=a+b
sub=a-b
multiply=a*b
div=a/b
modulus=a%b

print(sum)
print(sub)
print(div)
print(multiply)
print(modulus)
## assignment operator
# = assign
# += add and assign
x=7
x+=4
x-=11
print(x)
# -= add and assign
y=10
y-2==2
print(y)
# *= add and assign
x*=2
print(x)
# /= add and assign
## comparison operators
#3equal 3
#greator than
#less than
#not equal to
#> or =
#<=
value=(3==4)
print(value)
value2=(5>4)
value3=(5<4)
value4=(5!=7)
value5=(5>=3)
value6=(7<=10)
print(value,value6,value2,value3,value4)

#logical operators And,or,Not
## session
## given a list of st_name i want to add new student
stu_names=["hira","rabia","raza","abid"]
print(stu_names)
# add student fatima
stu_names.append('Fatima')
print(stu_names)
stu_names.append('Noreen')
print(stu_names)
## function is builtin  append,count,copy
## count values in a list
print(stu_names.count("raza"))
## count() can not be empty
## create a duplicate list of student name
copy_stu_names=stu_names.copy()
print(copy_stu_names)
copy_stu_names.append('hassan')
print(copy_stu_names)
## remove all elements from list
copy_stu_names.clear()
print(copy_stu_names)
## stu_names i have list
## another list of student they want to join
other_stu=["fiza",'Ali','jon']
## extend
stu_names.extend(other_stu)
print(stu_names)
##inset element at a specific location in list
## add 30 to list ## sequence type position number start from zero called index
list_num=[20,10,40,50]
list_num.insert(2,30)
print(list_num)
list_nu=[50,45,30,25]
list_nu.insert(2,40)
print(list_nu)
list_nu.insert(3,35)
print(list_nu)
## index concept
list_nu.append(40)
print(list_nu)
print(list_nu.index(40))
football_play=["rony",'messay',"rond","rony"]
print(football_play.index("rony"))
## pop() is used to remove its position if pos not define last will remove
remove_ele=list_nu.pop(3)
print(remove_ele)
## remove rony to avoid duplicate
football_play.remove("rony")
print(football_play)
## reverse()
football_play.reverse()
print(football_play)
##  Mapping variable dictionary update
stu_profile1={
    "name":"mary",
    "age": 24,
    "course":"data09",
    "gpa":3.4
}
print(stu_profile1)
stu_profile1["gpa"]=3.6
print(stu_profile1)
stu_profile1['grade']="gradeA"
print(stu_profile1)
## student belong to city islamabad, student has 3 other courses
## we use update fun()
stu_profile1.update(
    {
   "city" :"islamabad",
   "total other course":3
})
print(stu_profile1)
## strings
sample_text="we are learning data in python "
print(sample_text)
## upper- capital letters
print(sample_text.upper())
## lower- letters
print(sample_text.lower())
## len
print(len(sample_text))
#replace
print(sample_text.replace("analysis","science"))
## string slicing
print(sample_text[-22:])
print(sample_text[7:])
## conditional statements
## simple if
age=28
if age >=25:
 print("you are allowed to drive ")
 ## if and else
 age=28
if age >=25:
 print("you are allowed to drive ")
else:
    print('you must be atleast 25 to drive at night')
    ##if-elif-else
    age=28
if age <=15:
 print("you are  not allowed to drive ")
elif age >=18 and age <=25:
    print('greater and allow but not at night')
else:
  print('you are allowed')
  #mini practice of if else

  #If score is less than 40 then low , else if score is greater than equal 40 but less than equal to 70 then medium, else high score.
  score= 30
  if score <=  40 :
   print("score is less")
  elif  score >= 40 and  score<=70:
    print("score is low")
  else :
    print('high score')
# Out:
# 33 H.Zahra
# <class 'int'>
# <class 'str'>
# <class 'float'>
# ['banana', 'kiwi', 'orange', 'mango']
# ('banana', 'kiwi', 'orange', 'mango')
# range(0, 100)
# ['hina', 'gia', 'ria']
# ('hira', 'jia', 'bia')
# {'stu_profile1': {'name': 'mary', 'age': 24, 'course': 'data09', 'gpa': 3.4}, 'stu_profile2': {'name': 'jame', 'age': 24, 'course': 'data09', 'gpa': 3.0}}
# {'teach_profile1': {'name': 'rabia', 'age': 30, 'course': 'data09'}, 'teach_profile2': {'name': 'owais', 'age': 30, 'course_teaching': 'datascience09'}}
# {1, 4, 5}
# [1, 2, 3, 4]
# {1, 4, 5, 6}
# True False
# 26
# 14
# 3.3333333333333335
# 120
# 2
# 0
# 10
# 0
# False
# False True True False True
# ['hira', 'rabia', 'raza', 'abid']
# ['hira', 'rabia', 'raza', 'abid', 'Fatima']
# ['hira', 'rabia', 'raza', 'abid', 'Fatima', 'Noreen']
# 1
# ['hira', 'rabia', 'raza', 'abid', 'Fatima', 'Noreen']
# ['hira', 'rabia', 'raza', 'abid', 'Fatima', 'Noreen', 'hassan']
# []
# ...
